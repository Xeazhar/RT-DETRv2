# %%
import torch

print(f"Is CUDA available? {torch.cuda.is_available()}")
print(f"Current GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Is CUDA available? True
# Current GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import os
import sys

# 1. Get the absolute path to the 'rtdetrv2_pytorch' folder
# If you are running this from a script inside that folder:
current_path = os.getcwd()
print(f"📍 Current Working Directory: {current_path}")

# 2. Check if 'src' exists here
if os.path.exists(os.path.join(current_path, 'src')):
    print("✅ Found 'src' folder.")
    if current_path not in sys.path:
        sys.path.insert(0, current_path)
else:
    print("❌ 'src' folder NOT found! You might be in the wrong directory.")
    print("Contents of current folder:", os.listdir(current_path))
# Out:
# 📍 Current Working Directory: C:\Users\jazzb\rt-deterv2\RT-DETRv2
# ✅ Found 'src' folder.

# %%
import sys
import os

# 1. Get the absolute path to your rtdetrv2_pytorch folder
# Update this string to your actual folder path
project_root = 'C:/Users/jazzb/rt-deterv2/RT-DETRv2/'

if project_root not in sys.path:
    sys.path.insert(0, project_root)
    os.chdir(project_root) # Physically move the 'active' folder here

print(f"✅ Current Working Directory: {os.getcwd()}")
# Out:
# ✅ Current Working Directory: C:\Users\jazzb\rt-deterv2\RT-DETRv2

# %%
import os
import sys

# Ensure we are in the correct folder
project_root = 'C:/Users/jazzb/rt-deterv2/RT-DETRv2/'
os.chdir(project_root)

# Launch
# !python tools/train.py -c configs/rtdetrv2/rtdetrv2_r18vd_120e_coco.yml --seed 42
# Out:
# C:\Users\jazzb\anaconda3\envs\rtdetr_env\lib\site-packages\supervisely\__init__.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources  # isort: skip
# Traceback (most recent call last):
#   File "C:\Users\jazzb\rt-deterv2\RT-DETRv2\tools\train.py", line 12, in <module>
#     from src.solver import TASKS
#   File "C:\Users\jazzb\rt-deterv2\RT-DETRv2\tools\..\src\solver\__init__.py", line 6, in <module>
#     from .det_solver import DetSolver
#   File "C:\Users\jazzb\rt-deterv2\RT-DETRv2\tools\..\src\solver\det_solver.py", line 13, in <module>
#     from .det_engine import train_one_epoch, evaluate
#   File "C:\Users\jazzb\rt-deterv2\RT-DETRv2\tools\..\src\solver\det_engine.py", line 21, in <module>
#     from supervisely.nn.training import train_logger
# ...

# %%
import sys
from unittest.mock import MagicMock
import pkg_resources

# 1. Create a fake distribution to satisfy the 'supervisely' check
d = pkg_resources.Distribution(project_name='python-magic', version='0.4.27')
pkg_resources.working_set.add(d)

# 2. Mock the actual magic module in case the code tries to call it
mock_magic = MagicMock()
mock_magic.from_file.return_value = "image/jpeg" # Default response
sys.modules["magic"] = mock_magic

print("✅ 'python-magic' has been spoofed. Supervisely should now be satisfied.")
# Out:
# ✅ 'python-magic' has been spoofed. Supervisely should now be satisfied.
# C:\Users\jazzb\AppData\Local\Temp\ipykernel_13100\342613359.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
