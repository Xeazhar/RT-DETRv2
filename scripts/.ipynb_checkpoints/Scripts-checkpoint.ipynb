# %%
import os
import json

# --- Paths ---
image_dir = r"C:\Users\jazzb\Downloads\New_PersonA1\images"
json_path = r"C:\Users\jazzb\Downloads\New_PersonA1\results_cleaned.json"

# Keywords to look for (will strip everything before these)
keywords = ["train", "test", "val"]

# Load the JSON
with open(json_path, 'r') as f:
    data = json.load(f)

print(f"Starting cleanup in: {image_dir}")

renamed_count = 0
file_not_found_count = 0

# 1. Process the JSON entries and Rename Files
for img_entry in data['images']:
    old_name = img_entry['file_name']
    new_name = None
    
    # Logic: Split by '-' and find where the keyword starts
    parts = old_name.split('-')
    
    for kw in keywords:
        if kw in parts:
            kw_idx = parts.index(kw)
            # Reconstruct starting from the keyword
            new_name = "-".join(parts[kw_idx:])
            break
            
    # If a new name was generated and it's different from the old one
    if new_name and new_name != old_name:
        old_path = os.path.join(image_dir, old_name)
        new_path = os.path.join(image_dir, new_name)
        
        # Physical Rename on Disk
        if os.path.exists(old_path):
            # Handle potential name collisions
            if os.path.exists(new_path):
                print(f"Conflict: {new_name} already exists. Updating JSON but skipping file rename.")
            else:
                os.rename(old_path, new_path)
            
            # Update the JSON entry in memory
            img_entry['file_name'] = new_name
            renamed_count += 1
            print(f"Success: {old_name} -> {new_name}")
        else:
            # Update JSON even if file is missing (helps if files were moved/renamed manually)
            img_entry['file_name'] = new_name
            file_not_found_count += 1
            print(f"JSON Updated (Disk File Missing): {old_name} -> {new_name}")

# 2. Save the updated JSON (Overwrites the original)
with open(json_path, 'w') as f:
    json.dump(data, f, indent=4)

print("-" * 30)
print(f"Task Complete!")
print(f"Total entries updated in JSON: {renamed_count + file_not_found_count}")
print(f"Physical files renamed: {renamed_count}")
if file_not_found_count > 0:
    print(f"Warning: {file_not_found_count} files were not found on disk but updated in JSON.")
# Out:
# Starting cleanup in: C:\Users\jazzb\Downloads\New_PersonA1\images
# Success: 7eac5ec4-train-99.jpg -> train-99.jpg
# Success: 1dba7721-train-100.jpg -> train-100.jpg
# Success: 46165628-train-1.jpg -> train-1.jpg
# Success: d3e1d3f7-train-2.jpg -> train-2.jpg
# Success: 168ff6b9-train-3.jpg -> train-3.jpg
# Success: 9835ddc9-train-4.png -> train-4.png
# Success: 860c834c-train-5.jpg -> train-5.jpg
# Success: 0feb5026-train-6.jpg -> train-6.jpg
# Success: 1256b074-train-7.png -> train-7.png
# Success: 5c794540-train-8.jpg -> train-8.jpg
# Success: 7b307723-train-9.jpg -> train-9.jpg
# Success: 63bf7fc4-train-10.jpg -> train-10.jpg
# Success: 9387f623-train-11.jpg -> train-11.jpg
# Success: b304c196-train-12.png -> train-12.png
# Success: 5f6ffd74-train-13.jpg -> train-13.jpg
# Success: f831fb58-train-14.jpg -> train-14.jpg
# Success: a81f526a-train-15.jpg -> train-15.jpg
# Success: 096323d4-train-16.jpg -> train-16.jpg
# Success: bb5d3e27-train-17.jpg -> train-17.jpg
# Success: 90777176-train-18.jpg -> train-18.jpg
# Success: 9c330706-train-19.jpg -> train-19.jpg
# Success: e7b2460c-train-20.jpg -> train-20.jpg
# Success: 578cc365-train-21.jpg -> train-21.jpg
# Success: 3cbed563-train-22.jpg -> train-22.jpg
# Success: 789c4eba-train-23.jpg -> train-23.jpg
# Success: 369bb463-train-24.jpg -> train-24.jpg
# Success: 8530848c-train-25.jpg -> train-25.jpg
# Success: 9ea947fe-train-26.jpg -> train-26.jpg
# Success: 5b2c1591-train-27.jpg -> train-27.jpg
# Success: 0fd20c6d-train-28.jpg -> train-28.jpg
# Success: c9359ffe-train-29.jpg -> train-29.jpg
# Success: 87cb7b41-train-31.png -> train-31.png
# Success: d254fdec-train-32.jpg -> train-32.jpg
# Success: 7596df92-train-34.png -> train-34.png
# Success: ed2e5160-train-35.jpg -> train-35.jpg
# Success: 57000877-train-36.jpg -> train-36.jpg
# Success: d3d46fa9-train-37.jpg -> train-37.jpg
# Success: 1913b324-train-38.jpg -> train-38.jpg
# Success: 3a344259-train-39.jpg -> train-39.jpg
# Success: 7861011a-train-40.jpg -> train-40.jpg
# Success: c6bc2dfa-train-41.jpg -> train-41.jpg
# Success: 67462118-train-42.png -> train-42.png
# Success: 74ebcdb5-train-43.jpg -> train-43.jpg
# Success: cea8f62b-train-44.jpg -> train-44.jpg
# Success: 77ac06e5-train-45.jpg -> train-45.jpg
# Success: 9867d370-train-46.png -> train-46.png
# Success: 8d73210a-train-47.jpg -> train-47.jpg
# Success: 78d6fc01-train-48.jpg -> train-48.jpg
# Success: 46a86aee-train-49.jpg -> train-49.jpg
# Success: c19afd1f-train-50.jpg -> train-50.jpg
# Success: e1c16a84-train-51.jpg -> train-51.jpg
# Success: 85ca1973-train-52.jpg -> train-52.jpg
# Success: 48eb0913-train-54.jpg -> train-54.jpg
# Success: f55ce9ff-train-55.jpg -> train-55.jpg
# Success: c7106d0a-train-56.jpg -> train-56.jpg
# Success: 323b7ae8-train-57.jpg -> train-57.jpg
# Success: 94dfe753-train-60.png -> train-60.png
# Success: 9d03ae95-train-61.png -> train-61.png
# Success: 944529aa-train-62.jpg -> train-62.jpg
# Success: 9127fd2e-train-63.jpg -> train-63.jpg
# Success: 181f2e1f-train-64.png -> train-64.png
# Success: 295230b0-train-65.jpg -> train-65.jpg
# Success: 51b29e2f-train-66.jpg -> train-66.jpg
# Success: 822e3aa8-train-67.png -> train-67.png
# Success: 58a4f789-train-68.jpg -> train-68.jpg
# Success: 605f4af2-train-69.png -> train-69.png
# Success: 8bb3e125-train-71.jpg -> train-71.jpg
# Success: 221347ce-train-72.jpg -> train-72.jpg
# Success: 0897d81f-train-73.jpg -> train-73.jpg
# Success: b72052d1-train-74.jpg -> train-74.jpg
# Success: 286d5c44-train-75.jpg -> train-75.jpg
# Success: f92d3a67-train-76.jpg -> train-76.jpg
# Success: df153552-train-77.png -> train-77.png
# Success: 0973988b-train-78.png -> train-78.png
# Success: fe0eec34-train-79.png -> train-79.png
# Success: 9df4ddf6-train-80.jpg -> train-80.jpg
# Success: 04dde889-train-82.png -> train-82.png
# Success: 67643bdc-train-83.png -> train-83.png
# Success: 899bf7d8-train-84.jpg -> train-84.jpg
# Success: 77ce8d83-train-85.jpg -> train-85.jpg
# Success: 85e1dbad-train-86.jpg -> train-86.jpg
# Success: acf6f486-train-87.jpg -> train-87.jpg
# Success: 57de8c2b-train-88.png -> train-88.png
# Success: f92faa2f-train-89.jpg -> train-89.jpg
# Success: 14230868-train-90.jpg -> train-90.jpg
# Success: a2750447-train-91.jpg -> train-91.jpg
# Success: e3b46068-train-92.png -> train-92.png
# Success: 20fadfcd-train-93.png -> train-93.png
# Success: 08789a47-train-94.jpg -> train-94.jpg
# Success: 2905548c-train-96.jpg -> train-96.jpg
# Success: 7085f4a4-train-97.jpg -> train-97.jpg
# Success: b1683567-train-98.png -> train-98.png
# Success: 61d19018-train-199.jpg -> train-199.jpg
# Success: 1f9cf206-train-200.jpg -> train-200.jpg
# Success: 6b1c88ba-train-101.jpg -> train-101.jpg
# Success: ee7cd3ba-train-102.jpg -> train-102.jpg
# Success: 7d3cd9cb-train-103.png -> train-103.png
# Success: 13fd8b90-train-104.jpg -> train-104.jpg
# Success: c2f0ad0c-train-105.jpg -> train-105.jpg
# Success: e5228c8f-train-106.jpg -> train-106.jpg
# Success: 58cb3b3e-train-107.png -> train-107.png
# Success: f8332078-train-108.jpg -> train-108.jpg
# Success: 633e42d5-train-109.png -> train-109.png
# Success: 476030e0-train-110.jpg -> train-110.jpg
# Success: 09ce9e7a-train-111.jpg -> train-111.jpg
# Success: d710eadc-train-112.jpg -> train-112.jpg
# Success: a8406b3a-train-113.jpg -> train-113.jpg
# Success: b5db4fa8-train-114.jpg -> train-114.jpg
# Success: 204a9dcf-train-115.jpg -> train-115.jpg
# Success: 670d07bd-train-116.jpg -> train-116.jpg
# Success: c03092d4-train-117.jpg -> train-117.jpg
# Success: df492194-train-118.jpg -> train-118.jpg
# Success: 8eb93d13-train-119.jpg -> train-119.jpg
# Success: 3da12943-train-120.jpg -> train-120.jpg
# Success: f91b529c-train-121.jpg -> train-121.jpg
# Success: 6327e2bc-train-122.png -> train-122.png
# Success: 10c3db68-train-123.jpg -> train-123.jpg
# Success: 1b6a408e-train-124.jpg -> train-124.jpg
# Success: ace4a16c-train-125.jpg -> train-125.jpg
# Success: 31aee139-train-126.jpg -> train-126.jpg
# Success: 374fe46f-train-127.jpg -> train-127.jpg
# Success: 16093387-train-128.jpg -> train-128.jpg
# Success: c00d76f5-train-129.jpg -> train-129.jpg
# Success: beb7d5c4-train-130.jpg -> train-130.jpg
# Success: ad9684c1-train-131.jpg -> train-131.jpg
# Success: b38a341a-train-132.jpg -> train-132.jpg
# Success: 4a0ce7c8-train-133.jpg -> train-133.jpg
# Success: a53fc6d5-train-134.jpg -> train-134.jpg
# Success: 671f4c59-train-135.jpg -> train-135.jpg
# Success: 86cce70b-train-136.jpg -> train-136.jpg
# Success: 37295934-train-137.jpg -> train-137.jpg
# Success: 281a4a0e-train-138.jpg -> train-138.jpg
# Success: 162d6bba-train-139.jpg -> train-139.jpg
# Success: 3b92f0d4-train-140.jpg -> train-140.jpg
# Success: b7ead29b-train-141.jpg -> train-141.jpg
# Success: e3838351-train-142.jpg -> train-142.jpg
# Success: dca8aeac-train-143.jpg -> train-143.jpg
# Success: a1e912df-train-144.png -> train-144.png
# Success: 28c88767-train-145.jpg -> train-145.jpg
# Success: 2b636cda-train-146.jpg -> train-146.jpg
# Success: 71b06d27-train-147.jpg -> train-147.jpg
# Success: 5cd8263d-train-148.jpg -> train-148.jpg
# Success: f57b596e-train-149.jpg -> train-149.jpg
# Success: 78c7146e-train-150.jpg -> train-150.jpg
# Success: 51769e09-train-151.jpg -> train-151.jpg
# Success: ad5cc79a-train-152.jpg -> train-152.jpg
# Success: 7b056e3c-train-153.jpg -> train-153.jpg
# Success: 6946c74c-train-154.jpg -> train-154.jpg
# Success: 7c4fb981-train-155.png -> train-155.png
# Success: 6459b39b-train-156.jpg -> train-156.jpg
# Success: eca24903-train-157.jpg -> train-157.jpg
# Success: cef899fc-train-158.jpg -> train-158.jpg
# Success: 616d799a-train-159.jpg -> train-159.jpg
# Success: e56fc8ed-train-160.jpg -> train-160.jpg
# Success: f4b0ed09-train-161.jpg -> train-161.jpg
# Success: f8d38f95-train-162.jpg -> train-162.jpg
# Success: 5d332387-train-163.jpg -> train-163.jpg
# Success: 02c3ce34-train-165.jpg -> train-165.jpg
# Success: 6de4909a-train-166.jpg -> train-166.jpg
# Success: bd8bd59e-train-168.jpg -> train-168.jpg
# Success: 37875155-train-169.jpg -> train-169.jpg
# Success: 71aec998-train-170.jpg -> train-170.jpg
# Success: 0311cba4-train-171.jpg -> train-171.jpg
# Success: a6708014-train-172.jpg -> train-172.jpg
# Success: b1b3c560-train-173.jpg -> train-173.jpg
# Success: 999afb63-train-174.jpg -> train-174.jpg
# Success: 65903e78-train-175.jpg -> train-175.jpg
# Success: 83a0ad3e-train-176.jpg -> train-176.jpg
# Success: b76d1e4c-train-177.jpg -> train-177.jpg
# Success: 18903183-train-178.jpg -> train-178.jpg
# Success: f1a0d0df-train-179.jpg -> train-179.jpg
# Success: cc91c4d4-train-180.jpg -> train-180.jpg
# Success: f838f66e-train-181.jpg -> train-181.jpg
# Success: 008656d5-train-182.jpg -> train-182.jpg
# Success: 0d8bc53b-train-183.jpg -> train-183.jpg
# Success: a80db464-train-184.jpg -> train-184.jpg
# Success: f6b63157-train-185.jpg -> train-185.jpg
# Success: 2919a992-train-187.jpg -> train-187.jpg
# Success: a4aa913d-train-188.jpg -> train-188.jpg
# Success: 70801ca4-train-189.jpg -> train-189.jpg
# Success: c1b10a36-train-190.jpg -> train-190.jpg
# Success: bcf217a6-train-191.png -> train-191.png
# Success: b74049f9-train-192.jpg -> train-192.jpg
# Success: 41f77774-train-193.jpg -> train-193.jpg
# Success: 7ae775f7-train-194.jpg -> train-194.jpg
# Success: 7d12a7f8-train-195.jpg -> train-195.jpg
# Success: e4f7641d-train-196.jpg -> train-196.jpg
# Success: f5bc651b-train-197.jpg -> train-197.jpg
# Success: 48811749-train-198.jpg -> train-198.jpg
# Success: b9c5a734-train-300.jpg -> train-300.jpg
# Success: eb5bac12-train-201.jpg -> train-201.jpg
# Success: f6f5fe46-train-202.png -> train-202.png
# Success: add644ae-train-203.jpg -> train-203.jpg
# Success: 440677ca-train-204.jpg -> train-204.jpg
# Success: 7c1f34b2-train-205.jpg -> train-205.jpg
# Success: 2c4c7dcc-train-206.jpg -> train-206.jpg
# Success: 31fe179e-train-207.jpg -> train-207.jpg
# Success: ac536787-train-208.jpg -> train-208.jpg
# Success: 6e584b91-train-209.jpg -> train-209.jpg
# Success: 8f8732e1-train-210.jpg -> train-210.jpg
# Success: a4223d91-train-211.jpg -> train-211.jpg
# Success: c6c37fc6-train-212.jpg -> train-212.jpg
# Success: 1675544f-train-213.jpg -> train-213.jpg
# Success: 7dec091c-train-214.jpg -> train-214.jpg
# Success: fb92a1de-train-215.jpg -> train-215.jpg
# Success: 19277e7d-train-216.jpg -> train-216.jpg
# Success: 3280738c-train-217.jpg -> train-217.jpg
# Success: 80d5d34b-train-218.jpg -> train-218.jpg
# Success: c43ef33c-train-219.jpg -> train-219.jpg
# Success: 87f5dd3b-train-220.jpg -> train-220.jpg
# Success: 009cb20d-train-221.jpg -> train-221.jpg
# Success: 857d3f18-train-222.jpg -> train-222.jpg
# Success: 11d502cf-train-223.jpg -> train-223.jpg
# Success: b018cc93-train-224.jpg -> train-224.jpg
# Success: b96b1ede-train-225.jpg -> train-225.jpg
# Success: 1bb65882-train-226.jpg -> train-226.jpg
# Success: 58dca899-train-227.jpg -> train-227.jpg
# Success: 85c84dca-train-228.jpg -> train-228.jpg
# Success: 709994d4-train-229.jpg -> train-229.jpg
# Success: 3f3aace4-train-230.jpg -> train-230.jpg
# Success: 7443dbc2-train-231.jpg -> train-231.jpg
# Success: 58fc2ec8-train-232.jpg -> train-232.jpg
# Success: 65c849af-train-233.jpg -> train-233.jpg
# Success: e98e3da4-train-234.jpg -> train-234.jpg
# Success: c8587ebf-train-235.jpg -> train-235.jpg
# Success: b13de2b9-train-236.jpg -> train-236.jpg
# Success: d167e69c-train-237.jpg -> train-237.jpg
# Success: 82cd3cd8-train-238.png -> train-238.png
# Success: b877efe4-train-239.jpg -> train-239.jpg
# Success: a13c98a0-train-240.jpg -> train-240.jpg
# Success: 9e77b2d2-train-241.jpg -> train-241.jpg
# Success: 73a54c47-train-242.jpg -> train-242.jpg
# Success: f19547ac-train-243.jpg -> train-243.jpg
# Success: f3a6386a-train-244.jpg -> train-244.jpg
# Success: 6fe1c94c-train-245.jpg -> train-245.jpg
# Success: ffa631f1-train-246.jpg -> train-246.jpg
# Success: 16e70479-train-247.jpg -> train-247.jpg
# Success: a6ff1a2e-train-248.jpg -> train-248.jpg
# Success: 5c0d07ca-train-249.jpg -> train-249.jpg
# Success: 0362d86d-train-250.jpg -> train-250.jpg
# Success: 5bd193cd-train-251.jpg -> train-251.jpg
# Success: fc5a328e-train-252.jpg -> train-252.jpg
# Success: 5d89ac5b-train-253.jpg -> train-253.jpg
# Success: 72cd9846-train-254.jpg -> train-254.jpg
# Success: 8e318844-train-255.jpg -> train-255.jpg
# Success: 050add1b-train-256.jpg -> train-256.jpg
# Success: 1a7262fa-train-257.jpg -> train-257.jpg
# Success: 948e8b7a-train-258.jpg -> train-258.jpg
# Success: bf4a8a22-train-259.jpg -> train-259.jpg
# Success: 7c7ba0a9-train-260.jpg -> train-260.jpg
# Success: 23f04fb2-train-261.jpg -> train-261.jpg
# Success: 67ce5abb-train-263.jpg -> train-263.jpg
# Success: cbd23105-train-264.jpg -> train-264.jpg
# Success: ffd56d0a-train-265.jpg -> train-265.jpg
# Success: b5b356f6-train-266.jpg -> train-266.jpg
# Success: d9114fb9-train-267.jpg -> train-267.jpg
# Success: 95202d50-train-268.jpg -> train-268.jpg
# Success: 28024241-train-269.jpg -> train-269.jpg
# Success: 0527121a-train-270.jpg -> train-270.jpg
# Success: 7aeea703-train-271.jpg -> train-271.jpg
# Success: 568feaf3-train-272.jpg -> train-272.jpg
# Success: b2bb78fe-train-273.jpg -> train-273.jpg
# Success: 79afd67a-train-274.jpg -> train-274.jpg
# Success: 70e2f9da-train-275.jpg -> train-275.jpg
# Success: da590968-train-276.jpg -> train-276.jpg
# Success: 107ab6b8-train-277.jpg -> train-277.jpg
# Success: 4f7f9352-train-278.jpg -> train-278.jpg
# Success: 5245215f-train-279.jpg -> train-279.jpg
# Success: 2ed516f7-train-280.png -> train-280.png
# Success: 41108f10-train-281.jpg -> train-281.jpg
# Success: 37d5db6f-train-282.png -> train-282.png
# Success: bd603733-train-283.jpg -> train-283.jpg
# Success: f67bbdba-train-284.jpg -> train-284.jpg
# Success: f7a02923-train-285.jpg -> train-285.jpg
# Success: fda27a46-train-286.jpg -> train-286.jpg
# Success: c4177a01-train-287.jpg -> train-287.jpg
# Success: 6d678551-train-288.jpg -> train-288.jpg
# Success: 8227c2f1-train-289.jpg -> train-289.jpg
# Success: 51c0707a-train-290.jpg -> train-290.jpg
# Success: abcce546-train-291.jpg -> train-291.jpg
# Success: 8ada04af-train-292.jpg -> train-292.jpg
# Success: 23593418-train-293.jpg -> train-293.jpg
# Success: 5a408681-train-294.png -> train-294.png
# Success: 85680ea3-train-295.jpg -> train-295.jpg
# Success: 25833445-train-296.jpg -> train-296.jpg
# Success: e03a6eee-train-297.jpg -> train-297.jpg
# Success: e7aa33c5-train-298.jpg -> train-298.jpg
# Success: c301274a-train-365.jpg -> train-365.jpg
# Success: e2477ccc-train-366.jpg -> train-366.jpg
# Success: 11606119-train-301.jpg -> train-301.jpg
# Success: 5e675293-train-302.jpg -> train-302.jpg
# Success: 85e22260-train-303.jpg -> train-303.jpg
# Success: 2cbaf4b4-train-304.jpg -> train-304.jpg
# Success: be45859c-train-305.jpeg -> train-305.jpeg
# Success: 86559d57-train-306.png -> train-306.png
# Success: a651cdd0-train-307.jpg -> train-307.jpg
# Success: 8d4fc2e7-train-308.jpg -> train-308.jpg
# Success: 5f4b1255-train-309.jpg -> train-309.jpg
# Success: 51a6d0e4-train-310.png -> train-310.png
# Success: 10863c73-train-311.jpg -> train-311.jpg
# Success: d7dfd946-train-312.png -> train-312.png
# Success: 21717197-train-313.jpg -> train-313.jpg
# Success: e6c03f4d-train-314.jpg -> train-314.jpg
# Success: 21e9f173-train-315.jpg -> train-315.jpg
# Success: 918f457a-train-316.jpg -> train-316.jpg
# Success: d42d05c8-train-317.png -> train-317.png
# Success: c87d99bf-train-318.jpg -> train-318.jpg
# Success: 059c448b-train-320.jpg -> train-320.jpg
# Success: 1dd68e7e-train-321.jpg -> train-321.jpg
# Success: ecdf0a02-train-322.jpg -> train-322.jpg
# Success: 59bf9661-train-323.jpg -> train-323.jpg
# Success: 6fde8e4a-train-324.jpg -> train-324.jpg
# Success: 83dabfbb-train-325.jpg -> train-325.jpg
# Success: 1e7f054c-train-326.jpg -> train-326.jpg
# Success: 0adc9898-train-327.jpg -> train-327.jpg
# Success: 28322afa-train-328.jpg -> train-328.jpg
# Success: 297b5903-train-329.png -> train-329.png
# Success: badebfbc-train-330.png -> train-330.png
# Success: a18f3003-train-331.jpg -> train-331.jpg
# Success: 930e2fc5-train-332.jpg -> train-332.jpg
# Success: 9864700e-train-333.jpg -> train-333.jpg
# Success: 149c9fea-train-334.jpg -> train-334.jpg
# Success: 3b63d544-train-335.jpg -> train-335.jpg
# Success: 95b11a9a-train-336.jpg -> train-336.jpg
# Success: f88e9bfb-train-337.png -> train-337.png
# Success: ea1e77a3-train-338.jpg -> train-338.jpg
# Success: b59af84b-train-339.png -> train-339.png
# Success: 18488450-train-340.jpg -> train-340.jpg
# Success: 338568fd-train-341.png -> train-341.png
# Success: 2b97f706-train-342.jpg -> train-342.jpg
# Success: 59ae23d3-train-344.jpg -> train-344.jpg
# Success: a99265f1-train-346.jpg -> train-346.jpg
# Success: 3b494828-train-347.jpg -> train-347.jpg
# Success: 4a17b606-train-348.jpg -> train-348.jpg
# Success: 9291279f-train-349.jpg -> train-349.jpg
# Success: d766ce49-train-350.jpg -> train-350.jpg
# Success: 356c1d68-train-351.jpg -> train-351.jpg
# Success: 74da09fa-train-352.jpg -> train-352.jpg
# Success: b6166e37-train-353.png -> train-353.png
# Success: 31896877-train-354.jpg -> train-354.jpg
# Success: 26e60725-train-355.jpg -> train-355.jpg
# Success: 16b29ddb-train-356.jpg -> train-356.jpg
# Success: 4fb5bc3d-train-357.jpg -> train-357.jpg
# Success: fda5b764-train-358.jpg -> train-358.jpg
# Success: 0522a702-train-359.jpg -> train-359.jpg
# Success: 1015c78c-train-360.jpg -> train-360.jpg
# Success: 682a79cd-train-361.jpg -> train-361.jpg
# Success: 0210bb75-train-362.jpg -> train-362.jpg
# Success: bdc37579-train-363.jpg -> train-363.jpg
# Success: 2d49e0c4-train-364.PNG -> train-364.PNG
# ------------------------------
# Task Complete!
# Total entries updated in JSON: 350
# Physical files renamed: 350

# %%
import json
from pathlib import Path

# --- CONFIG ---
new_data_path = Path( r"C:\Users\jazzb\Downloads\New_PersonA1\results_cleaned.json")
master_json_path = Path(r"C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned\train\train.json")

def update_json_only():
    if not new_data_path.exists() or not master_json_path.exists():
        print("❌ Error: Path issues. Double-check your JSON locations.")
        return

    # 1. Load both files
    with open(master_json_path, 'r', encoding='utf-8') as f:
        master = json.load(f)
    with open(new_data_path, 'r', encoding='utf-8') as f:
        new_stuff = json.load(f)

    # 2. Get the next available IDs for Images and Annotations
    # This ensures the new data doesn't "clash" with what's already there
    curr_img_id = max([img['id'] for img in master['images']]) + 1 if master['images'] else 1
    curr_ann_id = max([ann['id'] for ann in master['annotations']]) + 1 if master['annotations'] else 1

    # 3. Add New Data
    # id_map stores: {old_id_from_PersonA : new_id_for_Master}
    id_map = {}

    print(f"🔄 Merging JSON entries...")

    for img in new_stuff['images']:
        old_id = img['id']
        id_map[old_id] = curr_img_id
        
        new_img_entry = img.copy()
        new_img_entry['id'] = curr_img_id
        master['images'].append(new_img_entry)
        curr_img_id += 1

    for ann in new_stuff['annotations']:
        if ann['image_id'] in id_map:
            new_ann_entry = ann.copy()
            new_ann_entry['id'] = curr_ann_id
            new_ann_entry['image_id'] = id_map[ann['image_id']]
            master['annotations'].append(new_ann_entry)
            curr_ann_id += 1

    # 4. Save back to the master train.json
    with open(master_json_path, 'w', encoding='utf-8') as f:
        json.dump(master, f, indent=4)

    print("-" * 40)
    print(f"✅ Master JSON Updated: {master_json_path}")
    print(f"📊 Final Image Count: {len(master['images'])}")
    print(f"📊 Final Bbox Count:  {len(master['annotations'])}")

if __name__ == "__main__":
    update_json_only()
# Out:
# 🔄 Merging JSON entries...
# ----------------------------------------
# ✅ Master JSON Updated: C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned\train\train.json
# 📊 Final Image Count: 1319
# 📊 Final Bbox Count:  3190

# %%
import json
import os
from pathlib import Path

# --- CONFIG ---
# Reading from PersonA folder
source_json = Path(r"C:\Users\jazzb\Downloads\New_PersonA1\result.json")
# Creating the NEW file name you requested
output_json = Path(r"C:\Users\jazzb\Downloads\New_PersonA1\results_cleaned.json")

def create_cleaned_json():
    if not source_json.exists():
        print(f"❌ Error: {source_json} not found!")
        return

    # 1. Read original JSON
    with open(source_json, 'r', encoding='utf-8') as f:
        data = json.load(f)

    print(f"🔄 Cleaning {len(data['images'])} image paths...")

    # 2. Strip paths but keep hashes + filenames
    for img in data['images']:
        # This turns "..\\..\\upload\\hash-name.jpg" into "hash-name.jpg"
        img['file_name'] = os.path.basename(img['file_name'])

    # 3. Write to the new file name
    with open(output_json, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=4)

    print(f"✅ Success! Created: {output_json.name}")
    print(f"📍 Full Path: {output_json}")
    if data['images']:
        print(f"📝 First entry is now: {data['images'][0]['file_name']}")

if __name__ == "__main__":
    create_cleaned_json()
# Out:
# 🔄 Cleaning 350 image paths...
# ✅ Success! Created: results_cleaned.json
# 📍 Full Path: C:\Users\jazzb\Downloads\New_PersonA1\results_cleaned.json
# 📝 First entry is now: 7eac5ec4-train-99.jpg

# %%
import json
import os
from pathlib import Path

# --- CONFIG ---
dataset_root = Path(r"C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned")

# Mapping the folder name to its corresponding JSON file
splits = {
    "train": "train.json",
    "val": "val.json",
    "test": "test.json"
}

def check_dataset_integrity():
    print("="*60)
    print("🔍 DATASET PAIRING & INTEGRITY CHECK")
    print("="*60)

    for folder_name, json_file in splits.items():
        split_path = dataset_root / folder_name
        img_dir = split_path / "images"
        json_path = split_path / json_file # Assumes JSON is in the split root

        if not img_dir.exists() or not json_path.exists():
            print(f"\n⏩ Skipping {folder_name.upper()}: Missing images or JSON.")
            continue

        # 1. Load Data
        with open(json_path, 'r') as f:
            data = json.load(f)
        
        # 2. Extract Names
        # Disk: Actual files in the folder
        disk_files = {f.lower().strip() for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))}
        
        # JSON: Filenames registered in the COCO file
        json_files = {os.path.basename(img['file_name']).lower().strip() for img in data['images']}
        
        # 3. Find Mismatches
        ghost_annotations = json_files - disk_files  # In JSON, but no file
        ghost_images = disk_files - json_files       # On Disk, but no JSON entry

        # 4. Check for Empty Annotations
        img_ids_with_anns = {ann['image_id'] for ann in data['annotations']}
        img_ids_all = {img['id'] for img in data['images']}
        empty_images_count = len(img_ids_all - img_ids_with_anns)

        # 5. Report Results
        print(f"\n📂 SPLIT: {folder_name.upper()}")
        print(f"   🖼️ Images on Disk: {len(disk_files)}")
        print(f"   📝 Entries in JSON: {len(json_files)}")
        
        if not ghost_annotations and not ghost_images:
            print("   ✅ PAIRING: Perfect Match.")
        else:
            if ghost_annotations:
                print(f"   ❌ GHOST ANNOTATIONS: {len(ghost_annotations)} (JSON entries missing physical files)")
                for g in list(ghost_annotations)[:3]: print(f"      - {g}")
            if ghost_images:
                print(f"   ⚠️  GHOST IMAGES: {len(ghost_images)} (Files on disk not used in JSON)")
                for g in list(ghost_images)[:3]: print(f"      - {g}")

        if empty_images_count > 0:
            print(f"   ⚠️  EMPTY IMAGES: {empty_images_count} images have 0 bounding boxes.")
        else:
            print("   ✅ LABELS: All images have at least one annotation.")
            
    print("\n" + "="*60)

if __name__ == "__main__":
    check_dataset_integrity()
# Out:
# ============================================================
# 🔍 DATASET PAIRING & INTEGRITY CHECK
# ============================================================
#
# 📂 SPLIT: TRAIN
#    🖼️ Images on Disk: 868
#    📝 Entries in JSON: 868
#    ✅ PAIRING: Perfect Match.
#    ✅ LABELS: All images have at least one annotation.
#
# 📂 SPLIT: VAL
#    🖼️ Images on Disk: 116
#    📝 Entries in JSON: 116
#    ✅ PAIRING: Perfect Match.
#    ✅ LABELS: All images have at least one annotation.
#
# 📂 SPLIT: TEST
#    🖼️ Images on Disk: 212
#    📝 Entries in JSON: 212
#    ✅ PAIRING: Perfect Match.
#    ✅ LABELS: All images have at least one annotation.
#
# ============================================================

# %%
import json
import cv2
import os
from pathlib import Path

# --- DIRECT MASTER PATHS ---
json_path = Path(r"C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned\train\train.json")
img_dir = Path(r"C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned\train\images")

def master_viewer():
    # Load the JSON
    if not json_path.exists():
        print(f"❌ JSON not found at: {json_path}")
        return

    with open(json_path, 'r') as f:
        data = json.load(f)

    # Map category IDs to names
    cat_map = {cat['id']: cat['name'] for cat in data['categories']}
    images = data['images']
    
    print(f"✅ Loaded {len(images)} images from Master JSON.")
    print("\n--- CONTROLS ---")
    print("▶️ Right Arrow / 'd': Next Image")
    print("◀️ Left Arrow / 'a':  Previous Image")
    print("❌ ESC or 'q':        Exit")
    
    idx = 0
    # Create a resizable window
    cv2.namedWindow("Master Train Reviewer", cv2.WINDOW_NORMAL)

    while True:
        img_info = images[idx]
        # Handle cases where file_name might be a full path or just a name
        fname = os.path.basename(img_info['file_name'])
        full_img_path = img_dir / fname
        
        # Load image
        img = cv2.imread(str(full_img_path))
        if img is None:
            print(f"⚠️ Image not found on disk: {fname}")
            # Overlay error message on a blank canvas if image is missing
            display_img = cv2.copyMakeBorder(cv2.imread(str(full_img_path)) if False else None, 0, 0, 0, 0, cv2.BORDER_CONSTANT)
        else:
            display_img = img.copy()
            # Get annotations for THIS specific image ID
            anns = [a for a in data['annotations'] if a['image_id'] == img_info['id']]
            
            # Draw boxes
            for ann in anns:
                x, y, w, h = map(int, ann['bbox'])
                label = cat_map.get(ann['category_id'], "Unknown")
                
                # Draw Box (Green)
                cv2.rectangle(display_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
                # Draw Label Background
                cv2.putText(display_img, f"{label}", (x, y - 10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        # UI Overlay (Top Left)
        status_text = f"[{idx+1}/{len(images)}] {fname} | Boxes: {len(anns) if img is not None else 0}"
        cv2.putText(display_img, status_text, (20, 40), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 3) # Outline
        cv2.putText(display_img, status_text, (20, 40), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 0), 1) # Text

        cv2.imshow("Master Train Reviewer", display_img)
        
        # Capture input
        key = cv2.waitKeyEx(0)

        if key == 27 or key == ord('q'): # ESC or Q to quit
            break
        elif key == 2555904 or key == ord('d'): # Right
            idx = (idx + 1) % len(images)
        elif key == 2424832 or key == ord('a'): # Left
            idx = (idx - 1) % len(images)

    cv2.destroyAllWindows()

if __name__ == "__main__":
    master_viewer()
# Out:
# ✅ Loaded 1183 images from Master JSON.
#
# --- CONTROLS ---
# ▶️ Right Arrow / 'd': Next Image
# ◀️ Left Arrow / 'a':  Previous Image
# ❌ ESC or 'q':        Exit

# %%
import sys
import os
import torch
import numpy as np
from PIL import Image, ImageDraw, UnidentifiedImageError
import matplotlib.pyplot as plt

# 1. SETUP ROOT PATHS
ROOT = r'C:\Users\jazzb\rt-deterv2\RT-DETRv2'
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)

from src.core import YAMLConfig
import src.zoo.rtdetr.rtdetr 
import src.solver

# 2. PATHS
CONFIG_NAME = 'rtdetrv2_r101vd_6x_coco.yml' 
CONFIG_PATH = os.path.join(ROOT, 'configs', 'rtdetrv2', CONFIG_NAME)
MODEL_PATH = os.path.join(ROOT, 'output', 'rtdetrv2_r101vd_6x_coco', 'best.pth')
TEST_IMAGE_DIR = r'C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned\test\images'

# 3. LOAD MODEL
cfg = YAMLConfig(CONFIG_PATH, resume=MODEL_PATH)
model = cfg.model

checkpoint = torch.load(MODEL_PATH, map_location='cpu')
if 'model' in checkpoint:
    model.load_state_dict(checkpoint['model'])
else:
    model.load_state_dict(checkpoint)

model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# 4. PREDICTION FUNCTION
def display_test_results(image_dir, num_images=15, threshold=0.50):
    all_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) 
                 if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    
    class_map = {
        0: "Alligator Cracks", 
        1: "Cracks", 
        2: "Potholes", 
        3: "Ravelling"
    }
    colors = ["red", "lime", "blue", "yellow"]
    
    displayed_count = 0

    for img_path in all_files:
        if displayed_count >= num_images:
            break
            
        try:
            img_pil = Image.open(img_path).convert('RGB')
        except (UnidentifiedImageError, OSError):
            continue 

        original_w, original_h = img_pil.size
        # Simple resize for inference
        input_tensor = torch.from_numpy(np.array(img_pil.resize((640, 640)))).permute(2, 0, 1).float() / 255.0
        
        with torch.no_grad():
            if hasattr(model, 'deploy'):
                model.deploy = True
            outputs = model(input_tensor.unsqueeze(0).to(device), 
                            torch.tensor([[original_h, original_w]]).to(device))

        if isinstance(outputs, dict):
            logits = outputs.get('pred_logits', outputs.get('logits'))
            boxes_raw = outputs.get('pred_boxes', outputs.get('boxes'))
            probs = logits.sigmoid()
            scores, labels = torch.max(probs, dim=-1)
            boxes = boxes_raw
        else:
            labels, boxes, scores = outputs

        draw = ImageDraw.Draw(img_pil)
        
        curr_labels = labels[0].cpu().numpy()
        curr_boxes = boxes[0].cpu().numpy()
        curr_scores = scores[0].cpu().numpy()

        # Check if we have any detections above threshold before showing image
        if not any(s > threshold for s in curr_scores):
            continue

        for i, s in enumerate(curr_scores):
            if s > threshold:
                cid = int(curr_labels[i])
                
                if cid in class_map:
                    label_name = class_map[cid]
                    color = colors[cid] if cid < len(colors) else "red"
                    
                    box = curr_boxes[i]
                    # Handle cxcywh normalized vs absolute coords
                    if box[2] <= 1.1 and box[3] <= 1.1:
                        cx, cy, bw, bh = box
                        coords = [(cx-bw/2)*original_w, (cy-bh/2)*original_h, (cx+bw/2)*original_w, (cy+bh/2)*original_h]
                    else:
                        coords = box.tolist()
                    
                    draw.rectangle(coords, outline=color, width=4)
                    draw.text((coords[0], coords[1]-15), f"{label_name} {s:.2f}", fill=color)

        plt.figure(figsize=(10, 6))
        plt.imshow(img_pil)
        plt.title(f"{os.path.basename(img_path)} (Conf > {threshold})")
        plt.axis('off')
        plt.show()
        
        displayed_count += 1

# SET TO 0.50 HERE
display_test_results(TEST_IMAGE_DIR, num_images=15, threshold=0.50)
# Out:
# Load PResNet101 state_dict
# C:\Users\jazzb\AppData\Local\Temp\ipykernel_2916\11626384.py:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(MODEL_PATH, map_location='cpu')

# %%
import json
from collections import Counter
from pathlib import Path

# --- CONFIG ---
dataset_root = Path(r"C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned")
splits = ["train", "val", "test"]

def get_complete_stats():
    presence_counts = Counter()      # Unique per image
    total_instance_counts = Counter() # Every single box
    total_images_all = 0
    total_annotations_all = 0

    print("="*70)
    print(f"{'STATISTICS REPORT':^70}")
    print("="*70)

    for split in splits:
        json_path = dataset_root / split / f"{split}.json"
        
        if not json_path.exists():
            print(f"⚠️  Skipping {split:<5}: {json_path.name} not found.")
            continue

        with open(json_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        cat_map = {cat['id']: cat['name'] for cat in data.get('categories', [])}
        image_damage_map = {img['id']: set() for img in data.get('images', [])}
        
        for ann in data.get('annotations', []):
            img_id = ann['image_id']
            cat_id = ann['category_id']
            
            if cat_id in cat_map:
                damage_name = cat_map[cat_id]
                
                # Count 1: Total Instances (All boxes)
                total_instance_counts[damage_name] += 1
                
                # Track for Count 2 (Presence per image)
                if img_id in image_damage_map:
                    image_damage_map[img_id].add(damage_name)

        # Count 2: Add unique occurrences per image to presence_counts
        for unique_types in image_damage_map.values():
            for damage_type in unique_types:
                presence_counts[damage_type] += 1
        
        total_images_all += len(data.get('images', []))
        total_annotations_all += len(data.get('annotations', []))
        print(f"✅ Processed {split:<5} : {len(data.get('images', []))} images")

    # Final Display Table
    print("\n" + "—"*70)
    print(f"{'DAMAGE TYPE':<25} | {'IN IMAGES':<15} | {'TOTAL BOXES'}")
    print("—"*70)
    
    # Use total_instance_counts to iterate so we don't miss anything
    all_classes = sorted(total_instance_counts.keys())
    
    for damage in all_classes:
        p_count = presence_counts[damage]
        t_count = total_instance_counts[damage]
        print(f"{damage:<25} | {p_count:<15} | {t_count}")

    print("—"*70)
    print(f"TOTAL UNIQUE IMAGES:      {total_images_all}")
    print(f"TOTAL INSTANCES (BOXES):  {total_annotations_all}")
    print("="*70)

if __name__ == "__main__":
    get_complete_stats()
# Out:
# ======================================================================
#                           STATISTICS REPORT
# ======================================================================
# ✅ Processed train : 1183 images
# ✅ Processed val   : 338 images
# ✅ Processed test  : 169 images
#
# ——————————————————————————————————————————————————————————————————————
# DAMAGE TYPE               | IN IMAGES       | TOTAL BOXES
# ——————————————————————————————————————————————————————————————————————
# Alligator Cracks          | 632             | 1035
# Cracks                    | 657             | 1185
# Potholes                  | 693             | 1204
# Ravelling                 | 411             | 568
# ——————————————————————————————————————————————————————————————————————
# TOTAL UNIQUE IMAGES:      1690
# TOTAL INSTANCES (BOXES):  3992
# ======================================================================

# %%
import sys
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 1. SETUP ROOT PATHS
ROOT = r'C:\Users\jazzb\rt-deterv2\RT-DETRv2'
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)

from src.core import YAMLConfig
from src.solver import TASKS
import src.zoo.rtdetr.rtdetr 

# 2. PATHS
CONFIG_NAME = 'rtdetrv2_r101vd_6x_coco.yml' 
CONFIG_PATH = os.path.join(ROOT, 'configs', 'rtdetrv2', CONFIG_NAME)
MODEL_PATH = os.path.join(ROOT, 'output', 'rtdetrv2_r101vd_6x_coco', 'best.pth')

# 3. LOAD CONFIG AND SOLVER
cfg = YAMLConfig(CONFIG_PATH, resume=MODEL_PATH)
solver = TASKS[cfg.yaml_cfg['task']](cfg)

# 4. RUN STANDARD COCO EVALUATION (mAP)
print("Running COCO Evaluation...")
solver.val() 

# 5. GENERATE CONFUSION MATRIX
def generate_confusion_matrix(solver, threshold=0.7):
    print(f"Generating Confusion Matrix (Threshold: {threshold})...")
    
    all_preds = []
    all_gts = []
    class_names = ["Alligator Cracks", "Cracks", "Potholes", "Ravelling"]
    
    solver.model.eval()
    device = next(solver.model.parameters()).device
    
    with torch.no_grad():
        for batch in solver.val_dataloader:
            images, targets = batch
            images = images.to(device)
            orig_target_sizes = torch.stack([t['orig_size'] for t in targets]).to(device)
            
            outputs = solver.model(images, orig_target_sizes)
            
            # --- FIX: Handling Dictionary Output ---
            if isinstance(outputs, dict):
                logits = outputs['pred_logits']  # Shape: [batch, query, classes]
                probs = logits.sigmoid()         # Convert to 0-1 confidence
                scores, labels = torch.max(probs, dim=-1) 
            else:
                # Fallback if it actually returned a tuple
                labels, _, scores = outputs 

            for i in range(len(targets)):
                gt_labels = targets[i]['labels'].cpu().numpy()
                curr_labels = labels[i].cpu().numpy()
                curr_scores = scores[i].cpu().numpy()
                
                # Filter by confidence
                mask = curr_scores > threshold
                valid_preds = curr_labels[mask]
                
                # Matching: Top pred vs First GT
                if len(valid_preds) > 0 and len(gt_labels) > 0:
                    all_preds.append(valid_preds[0])
                    all_gts.append(gt_labels[0])

    # Plot Confusion Matrix
    if not all_preds:
        print("Error: No detections found above threshold. Try lowering the threshold.")
        return

    cm = confusion_matrix(all_gts, all_preds, labels=range(len(class_names)))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    
    fig, ax = plt.subplots(figsize=(10, 8))
    disp.plot(cmap='Blues', ax=ax, xticks_rotation=45)
    plt.title(f'Confusion Matrix (Threshold: {threshold})')
    plt.show()

# Run CM
generate_confusion_matrix(solver, threshold=0.7)
# Out:
# Running COCO Evaluation...
# Load PResNet101 state_dict
# building val_dataloader with batch_size=4...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Resume checkpoint from C:\Users\jazzb\rt-deterv2\RT-DETRv2\output\rtdetrv2_r101vd_6x_coco\best.pth
# Load last_epoch
# Load model.state_dict
# Load criterion.state_dict
# Load postprocessor.state_dict
# Load ema.state_dict
# Load scaler.state_dict
# Test:  [ 0/85]  eta: 0:27:32    time: 19.4411  data: 17.8643  max mem: 1159
# Test:  [10/85]  eta: 0:02:27    time: 1.9651  data: 1.6290  max mem: 1167
# Test:  [20/85]  eta: 0:01:14    time: 0.2330  data: 0.0052  max mem: 1167
# Test:  [30/85]  eta: 0:00:46    time: 0.2364  data: 0.0052  max mem: 1167
# Test:  [40/85]  eta: 0:00:31    time: 0.2280  data: 0.0055  max mem: 1167
# Test:  [50/85]  eta: 0:00:21    time: 0.2394  data: 0.0052  max mem: 1167
# Test:  [60/85]  eta: 0:00:13    time: 0.2373  data: 0.0051  max mem: 1167
# Test:  [70/85]  eta: 0:00:07    time: 0.2294  data: 0.0052  max mem: 1167
# Test:  [80/85]  eta: 0:00:02    time: 0.2373  data: 0.0049  max mem: 1167
# Test:  [84/85]  eta: 0:00:00    time: 0.2340  data: 0.0044  max mem: 1167
# Test: Total time: 0:00:39 (0.4697 s / it)
# Averaged stats:
# Accumulating evaluation results...
# DONE (t=0.54s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.325
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.570
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.330
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.474
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.570
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.347
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.614
# Generating Confusion Matrix (Threshold: 0.3)...

# %%
import sys
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support

# ================================
# 1. SETUP ROOT PATHS
# ================================
ROOT = r'C:\Users\jazzb\rt-deterv2\RT-DETRv2'
if ROOT not in sys.path:
    sys.path.insert(0, ROOT)
os.chdir(ROOT)

from src.core import YAMLConfig
from src.solver import TASKS
import src.zoo.rtdetr.rtdetr

# ================================
# 2. PATHS
# ================================
CONFIG_NAME = 'rtdetrv2_r101vd_6x_coco.yml'
CONFIG_PATH = os.path.join(ROOT, 'configs', 'rtdetrv2', CONFIG_NAME)
MODEL_PATH = os.path.join(ROOT, 'output', 'rtdetrv2_r101vd_6x_coco', 'best.pth')

# ================================
# 3. LOAD CONFIG AND SOLVER
# ================================
cfg = YAMLConfig(CONFIG_PATH, resume=MODEL_PATH)
solver = TASKS[cfg.yaml_cfg['task']](cfg)
solver.eval()  # ensures model is in eval mode
device = solver.device
model = solver.model

# ================================
# 4. CLASS NAMES
# ================================
CLASS_NAMES = ["Alligator Cracks", "Cracks", "Potholes", "Ravelling"]

# ================================
# 5. HELPER FUNCTIONS (fixed IoU alignment)
# ================================
def evaluate_loader(loader, split_name="VAL", threshold=0.7, export_csv=True):
    all_preds, all_gts, iou_list = [], [], []

    model.eval()
    with torch.no_grad():
        for images, targets in loader:
            images = images.to(device)
            orig_sizes = torch.stack([t['orig_size'] for t in targets]).to(device)

            outputs = model(images, orig_sizes)
            logits = outputs['pred_logits']
            boxes = outputs['pred_boxes']
            probs = logits.sigmoid()
            scores, labels = probs.max(dim=-1)

            for i in range(len(targets)):
                gt_labels = targets[i]['labels'].cpu().numpy()
                gt_boxes = targets[i]['boxes'].cpu().numpy()

                curr_labels = labels[i].cpu().numpy()
                curr_scores = scores[i].cpu().numpy()
                curr_boxes = boxes[i].cpu().numpy()

                mask = curr_scores > threshold
                valid_preds = curr_labels[mask]
                valid_boxes = curr_boxes[mask]

                # --- match each predicted box with GT (first GT for simplicity) ---
                for pred_idx, pred_label in enumerate(valid_preds):
                    all_preds.append(pred_label)
                    # Use first GT label for this image if exists
                    if len(gt_labels) > 0:
                        all_gts.append(gt_labels[0])
                        # IoU between this pred box and all GT boxes: take max
                        best_iou = max([compute_iou(valid_boxes[pred_idx], gb) for gb in gt_boxes]) if len(gt_boxes) > 0 else 0
                        iou_list.append(best_iou)
                    else:
                        all_gts.append(-1)  # background / no GT
                        iou_list.append(0)

    # Filter out invalid GTs (-1)
    mask_valid = np.array(all_gts) != -1
    all_gts = np.array(all_gts)[mask_valid]
    all_preds = np.array(all_preds)[mask_valid]
    iou_list = np.array(iou_list)[mask_valid]

    # Compute metrics
    precision, recall, f1, _ = precision_recall_fscore_support(
        all_gts, all_preds, labels=list(range(len(CLASS_NAMES))), zero_division=0
    )

    print(f"\n=== {split_name} Metrics (Threshold={threshold}) ===")
    for idx, name in enumerate(CLASS_NAMES):
        print(f"{name}: P={precision[idx]:.3f}, R={recall[idx]:.3f}, F1={f1[idx]:.3f}")

    # Confusion Matrix
    cm = confusion_matrix(all_gts, all_preds, labels=list(range(len(CLASS_NAMES))))
    disp = ConfusionMatrixDisplay(cm, display_labels=CLASS_NAMES)
    fig, ax = plt.subplots(figsize=(10,8))
    disp.plot(ax=ax, cmap='Blues', xticks_rotation=45)
    plt.title(f"{split_name} Confusion Matrix")
    plt.show()

    # IoU stats
    if len(iou_list) > 0:
        print(f"{split_name} IoU: mean={iou_list.mean():.3f}, min={iou_list.min():.3f}, max={iou_list.max():.3f}")

    # Optional CSV export
    if export_csv:
        df = pd.DataFrame({"GT": all_gts, "Pred": all_preds, "IoU": iou_list})
        csv_file = f"{split_name.lower()}_results.csv"
        df.to_csv(csv_file, index=False)
        print(f"{split_name} results exported to {csv_file}")
# ================================
# 6. RUN VAL + TEST
# ================================
print(">>> Evaluating VAL set")
evaluate_loader(solver.val_dataloader, split_name="VAL", threshold=0.7)

# If you added test_dataloader manually:
if hasattr(solver, "test_dataloader"):
    print("\n>>> Evaluating CUSTOM TEST set")
    evaluate_loader(solver.test_dataloader, split_name="TEST", threshold=0.7)
else:
    print("\n>>> No test_dataloader found. Add it in cfg.yaml if needed.")
# Out:
# Load PResNet101 state_dict
# C:\Users\jazzb\rt-deterv2\RT-DETRv2\src\core\workspace.py:149: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   return module(**final_params)
# C:\Users\jazzb\rt-deterv2\RT-DETRv2\src\solver\_solver.py:144: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(path, map_location='cpu')
# building val_dataloader with batch_size=4...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Resume checkpoint from C:\Users\jazzb\rt-deterv2\RT-DETRv2\output\rtdetrv2_r101vd_6x_coco\best.pth
# Load last_epoch
# Load model.state_dict
# Load criterion.state_dict
# Load postprocessor.state_dict
# Load ema.state_dict
# Load scaler.state_dict
# >>> Evaluating VAL set
#
# === VAL Metrics (Threshold=0.7) ===
# Alligator Cracks: P=0.961, R=0.860, F1=0.907
# Cracks: P=0.983, R=0.950, F1=0.966
# Potholes: P=0.900, R=0.973, F1=0.935
# Ravelling: P=0.938, R=0.909, F1=0.923
# VAL IoU: mean=0.000, min=0.000, max=0.000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 126
#     122 # ================================
#     123 # 6. RUN VAL + TEST
#     124 # ================================
#     125 print(">>> Evaluating VAL set")
# --> 126 evaluate_loader(solver.val_dataloader, split_name="VAL", threshold=0.7)
#     128 # If you added test_dataloader manually:
#     129 if hasattr(solver, "test_dataloader"):
#
# Cell In[10], line 117, in evaluate_loader(loader, split_name, threshold, export_csv)
#     115 # Optional CSV export
#     116 if export_csv:
# --> 117     df = pd.DataFrame({"GT": all_gts, "Pred": all_preds, "IoU": iou_list})
#     118     csv_file = f"{split_name.lower()}_results.csv"
#     119     df.to_csv(csv_file, index=False)
#
# File ~\anaconda3\envs\RT\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     763     mgr = self._init_mgr(
#     764         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     765     )
#     767 elif isinstance(data, dict):
#     768     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770 elif isinstance(data, ma.MaskedArray):
#     771     from numpy.ma import mrecords
#
# File ~\anaconda3\envs\RT\Lib\site-packages\pandas\core\internals\construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File ~\anaconda3\envs\RT\Lib\site-packages\pandas\core\internals\construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File ~\anaconda3\envs\RT\Lib\site-packages\pandas\core\internals\construction.py:643, in _extract_index(data)
#     641 if have_raw_arrays:
#     642     if len(raw_lengths) > 1:
# --> 643         raise ValueError("All arrays must be of the same length")
#     645     if have_dicts:
#     646         raise ValueError(
#     647             "Mixing dicts with non-Series may lead to ambiguous ordering."
#     648         )
#
# ValueError: All arrays must be of the same length

# %%
import os

BASE_DIR = r"C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned"

splits = {
    "train": os.path.join(BASE_DIR, "train", "images"),
    "val": os.path.join(BASE_DIR, "val", "images"),
    "test": os.path.join(BASE_DIR, "test", "images"),
}

# Image extensions to count
IMG_EXTS = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff")

counts = {}

for split, path in splits.items():
    if not os.path.exists(path):
        print(f"{split}: ❌ path not found")
        counts[split] = 0
        continue

    files = [
        f for f in os.listdir(path)
        if f.lower().endswith(IMG_EXTS)
    ]
    counts[split] = len(files)

total = sum(counts.values())

print("\n📊 Dataset Split Summary")
print("-" * 30)

for split in ["train", "val", "test"]:
    count = counts[split]
    pct = (count / total * 100) if total > 0 else 0
    print(f"{split:5s}: {count:4d} images  ({pct:5.2f}%)")

print("-" * 30)
print(f"TOTAL : {total} images")
# Out:
# 📊 Dataset Split Summary
# ------------------------------
# train: 1183 images  (70.00%)
# val  :  338 images  (20.00%)
# test :  169 images  (10.00%)
# ------------------------------
# TOTAL : 1690 images

# %%
import json
import random
from pathlib import Path
import shutil
from collections import defaultdict

# ========================
# CONFIG
# ========================
BASE_DIR = Path(r"C:\Users\jazzb\rt-deterv2\RT-DETRv2\dataset\cleaned")
COMBINED_DIR = BASE_DIR / "all"
COMBINED_IMG_DIR = COMBINED_DIR / "images"
COMBINED_JSON = COMBINED_DIR / "all.json"

RANDOM_SEED = 42
TRAIN_RATIO = 0.7
VAL_RATIO = 0.2
TEST_RATIO = 0.1

SPLITS = ["train", "val", "test"]

# ========================
# CREATE SPLIT FOLDERS
# ========================
for split in SPLITS:
    split_dir = BASE_DIR / split
    img_dir = split_dir / "images"
    img_dir.mkdir(parents=True, exist_ok=True)

# ========================
# LOAD COMBINED JSON
# ========================
with open(COMBINED_JSON, "r") as f:
    coco = json.load(f)

images = coco["images"]
annotations = coco["annotations"]
categories = coco["categories"]

# ========================
# MAP IMAGE_ID -> ANNOTATIONS
# ========================
img_id_to_anns = defaultdict(list)
for ann in annotations:
    img_id_to_anns[ann["image_id"]].append(ann)

# ========================
# SHUFFLE + SPLIT
# ========================
random.seed(RANDOM_SEED)
random.shuffle(images)

n_total = len(images)
n_train = int(n_total * TRAIN_RATIO)
n_val = int(n_total * VAL_RATIO)

split_map = {
    "train": images[:n_train],
    "val": images[n_train:n_train + n_val],
    "test": images[n_train + n_val:],
}

# ========================
# BUILD SPLIT FUNCTION
# ========================
def build_split(split_name, imgs):
    split_dir = BASE_DIR / split_name
    img_dir = split_dir / "images"
    
    new_images = []
    new_annotations = []
    ann_counter = 1

    for idx, img in enumerate(imgs, start=1):
        old_id = img["id"]
        new_id = idx
        new_name = f"{split_name}-{idx}.jpg"

        src_path = COMBINED_IMG_DIR / img["file_name"]
        dst_path = img_dir / new_name

        # Copy image
        shutil.copy(src_path, dst_path)

        # Add to new JSON
        new_images.append({
            "id": new_id,
            "file_name": new_name,
            "width": img["width"],
            "height": img["height"],
        })

        # Add annotations
        for ann in img_id_to_anns[old_id]:
            new_annotations.append({
                "id": ann_counter,
                "image_id": new_id,
                "category_id": ann["category_id"],
                "bbox": ann["bbox"],
                "area": ann["area"],
                "iscrowd": ann.get("iscrowd", 0),
            })
            ann_counter += 1

    # Save JSON
    out_json = split_dir / f"{split_name}.json"
    with open(out_json, "w") as f:
        json.dump({
            "images": new_images,
            "annotations": new_annotations,
            "categories": categories
        }, f, indent=2)

    print(f"✅ {split_name}: {len(new_images)} images, {len(new_annotations)} annotations saved")

# ========================
# EXECUTE SPLIT
# ========================
for split_name, imgs in split_map.items():
    build_split(split_name, imgs)

print("\n🎉 Dataset successfully split into train/val/test with proper naming!")
# Out:
# ✅ train: 1183 images, 2749 annotations saved
# ✅ val: 338 images, 845 annotations saved
# ✅ test: 169 images, 398 annotations saved
#
# 🎉 Dataset successfully split into train/val/test with proper naming!
